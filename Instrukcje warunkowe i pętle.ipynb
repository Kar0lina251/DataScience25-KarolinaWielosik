# %%
temperature = 17 

if temperature > 25: 

    print("Ciepło") 

elif temperature > 15: 

    print("W sam raz") 

else: 

    print("Chłodno") 

number = int(input("Podaj liczbę: "))

if number % 2 == 0:
    print(f"Liczba {number} jest parzysta")
else:
    print(f"Liczba {number} jest nieparzysta")

for i in range(1, 11):
    if i < 10:
        print(i, end=", ")
    else:
        print(i)

for i in range(1, 11):
    if i < 10:
        print(i, end=", ")
    else:
        print(i)

count = 0
while count < 5:
    print("To jest iteracja nr", count + 1)
    count += 1
