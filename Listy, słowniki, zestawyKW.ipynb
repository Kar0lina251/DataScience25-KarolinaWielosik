# %%
fruits = ["jabłko", "banan", "malina"]
person = {"name": "Ala", "age": 22}
numbers = {1, 2, 3, 3}

fruits.append("gruszka")
print("Lista owoców po dodaniu nowego elementu:", fruits)

second_fruit = fruits[1]
print("Drugi element z listy fruits:", second_fruit)

numbers_list = [4, 8, 15, 16, 23, 42]
average = sum(numbers_list) / len(numbers_list)
print("Średnia z listy:", average)

for key, value in person.items():
    print(key, ":", value)
# Out:
# Lista owoców po dodaniu nowego elementu: ['jabłko', 'banan', 'malina', 'gruszka']
# Drugi element z listy fruits: banan
# Średnia z listy: 18.0
# name : Ala
# age : 22
